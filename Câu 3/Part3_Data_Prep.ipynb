# %%
import pandas as pd
import numpy as np
import warnings
import os

# Tắt cảnh báo để notebook dễ nhìn hơn
warnings.filterwarnings('ignore')

# Cố định Seed để kết quả tái lập được 100% (Tiêu chí 8 điểm báo cáo)
SEED = 42
np.random.seed(SEED)

# Khai báo đường dẫn tương đối theo cấu trúc project
RAW_DIR = '../data/raw/'
PROCESSED_DIR = '../data/processed/'

print("Đang tải dữ liệu...")
sales = pd.read_csv(RAW_DIR + 'sales.csv')
sample_sub = pd.read_csv(RAW_DIR + 'sample_submission.csv')
orders = pd.read_csv(RAW_DIR + 'orders.csv')
web_traffic = pd.read_csv(RAW_DIR + 'web_traffic.csv')
promotions = pd.read_csv(RAW_DIR + 'promotions.csv')

print("Tải dữ liệu thành công!")
